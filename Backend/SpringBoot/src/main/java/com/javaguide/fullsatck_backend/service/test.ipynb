// %% [markdown]
// ##Collection
// List

// %%
System.out.printf("Hello World");
// Out:
// Hello World
// java.io.PrintStream@4f965969

// %%
var names = listOf("Rohit", "Rohit2", "Rohit3")
println(names)
// Out:
// [Rohit, Rohit2, Rohit3]

// %%
names.contains("Rohit3")
// Out:
// true
