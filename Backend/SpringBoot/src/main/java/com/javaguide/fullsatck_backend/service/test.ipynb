// %% [markdown]
// ##Collection
// List

// %%
println("Hello World");
// Out:
// Hello World

// %%
var names = listOf("Rohit", "Rohit2", "Rohit3")
println(names)
// Out:
// [Rohit, Rohit2, Rohit3]

// %%
println(names.contains("Rohit3"))
// Out:
// true
